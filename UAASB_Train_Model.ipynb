# %%
# !pip install -q tflite-model-maker
# Out:
#      |████████████████████████████████| 616 kB 8.4 MB/s
#      |████████████████████████████████| 1.1 MB 41.7 MB/s
#      |████████████████████████████████| 3.4 MB 42.2 MB/s
#      |████████████████████████████████| 1.1 MB 59.1 MB/s
#      |████████████████████████████████| 6.4 MB 45.8 MB/s
#      |████████████████████████████████| 1.2 MB 59.9 MB/s
#      |████████████████████████████████| 596 kB 77.1 MB/s
#      |████████████████████████████████| 77 kB 6.0 MB/s
#      |████████████████████████████████| 87 kB 7.1 MB/s
#      |████████████████████████████████| 840 kB 42.5 MB/s
#      |████████████████████████████████| 237 kB 58.1 MB/s
#      |████████████████████████████████| 120 kB 55.1 MB/s
#      |████████████████████████████████| 25.3 MB 1.6 MB/s
#      |████████████████████████████████| 99 kB 9.8 MB/s
#      |████████████████████████████████| 47.8 MB 46 kB/s
#      |████████████████████████████████| 352 kB 51.2 MB/s
#      |████████████████████████████████| 462 kB 46.4 MB/s
#      |████████████████████████████████| 213 kB 66.6 MB/s
#   Building wheel for fire (setup.py) ... done
#   Building wheel for py-cpuinfo (setup.py) ... done

# %%
import numpy as np
import os

from tflite_model_maker import configs
from tflite_model_maker import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import text_classifier
from tflite_model_maker.text_classifier import DataLoader

import tensorflow as tf
assert tf.__version__.startswith('2')
tf.get_logger().setLevel('ERROR')

from datetime import datetime # Current date time in local system print(datetime.now())

# Example from google storage
# data_file = tf.keras.utils.get_file(fname='comment-spam-extras.csv', origin='https://storage.googleapis.com/laurencemoroney-blog.appspot.com/jm_blog_comments_extras.csv', extract=False)

# Example from local file
myFile = 'tensor-csv-dataset.csv'
fullPath = os.path.abspath("./" + myFile)
origin = 'file://'+fullPath

datasetTime = datetime.now().isoformat()
print(datasetTime)

data_file = tf.keras.utils.get_file(fname='tensor-csv-dataset-loaded' + datasetTime + '.csv', origin=origin, extract=False)

spec = model_spec.get('average_word_vec')
spec.num_words = 2000
spec.seq_len = 30
spec.wordvec_dim = 7

data = DataLoader.from_csv(
      filename=data_file,
      text_column='commenttext', 
      label_column='spam', 
      model_spec=spec,
      delimiter=',',
      shuffle=True,
      is_training=True)

train_data, test_data = data.split(0.9)

model = text_classifier.create(train_data, model_spec=spec, epochs=50)

model.export(export_dir="/content/js_export/", export_format=[ExportFormat.TFJS, ExportFormat.LABEL, ExportFormat.VOCAB])
# !zip -r /content/js_export/ModelFiles.zip /content/js_export/
# Out:
# 2022-04-07T16:15:34.138156
# Downloading data from file:///content/tensor-csv-dataset.csv
# 720896/716168 [==============================] - 0s 0us/step
# 729088/716168 [==============================] - 0s 0us/step
# 204/204 [==============================] - 1s 2ms/step - loss: 0.6883 - accuracy: 0.5430
# Epoch 2/2
# 204/204 [==============================] - 0s 2ms/step - loss: 0.6764 - accuracy: 0.5859
# Epoch 3/3
# 204/204 [==============================] - 0s 2ms/step - loss: 0.6505 - accuracy: 0.6440
# Epoch 4/4
# 204/204 [==============================] - 1s 2ms/step - loss: 0.6091 - accuracy: 0.6972
# Epoch 5/5
# 204/204 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.7361
# Epoch 6/6
# 204/204 [==============================] - 0s 2ms/step - loss: 0.5196 - accuracy: 0.7615
# Epoch 7/7
# 204/204 [==============================] - 1s 2ms/step - loss: 0.4760 - accuracy: 0.7938
# Epoch 8/8
# 204/204 [==============================] - 0s 2ms/step - loss: 0.4464 - accuracy: 0.8036
# Epoch 9/9
# 204/204 [==============================] - 0s 2ms/step - loss: 0.4167 - accuracy: 0.8145
# Epoch 10/10
# 204/204 [==============================] - 1s 2ms/step - loss: 0.4040 - accuracy: 0.8220
# Epoch 11/11
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3883 - accuracy: 0.8261
# Epoch 12/12
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3747 - accuracy: 0.8362
# Epoch 13/13
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3619 - accuracy: 0.8453
# Epoch 14/14
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3567 - accuracy: 0.8436
# Epoch 15/15
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3478 - accuracy: 0.8499
# Epoch 16/16
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8509
# Epoch 17/17
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3323 - accuracy: 0.8563
# Epoch 18/18
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3294 - accuracy: 0.8578
# Epoch 19/19
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3247 - accuracy: 0.8632
# Epoch 20/20
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3210 - accuracy: 0.8631
# Epoch 21/21
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3162 - accuracy: 0.8634
# Epoch 22/22
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3179 - accuracy: 0.8655
# Epoch 23/23
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3113 - accuracy: 0.8670
# Epoch 24/24
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8678
# Epoch 25/25
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3040 - accuracy: 0.8730
# Epoch 26/26
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3032 - accuracy: 0.8713
# Epoch 27/27
# 204/204 [==============================] - 1s 3ms/step - loss: 0.3028 - accuracy: 0.8715
# Epoch 28/28
# 204/204 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 0.8736
# Epoch 29/29
# 204/204 [==============================] - 1s 2ms/step - loss: 0.3001 - accuracy: 0.8742
# Epoch 30/30
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2977 - accuracy: 0.8744
# Epoch 31/31
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2919 - accuracy: 0.8811
# Epoch 32/32
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.8745
# Epoch 33/33
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 0.8811
# Epoch 34/34
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2867 - accuracy: 0.8801
# Epoch 35/35
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2870 - accuracy: 0.8808
# Epoch 36/36
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2834 - accuracy: 0.8830
# Epoch 37/37
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2853 - accuracy: 0.8810
# Epoch 38/38
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2828 - accuracy: 0.8833
# Epoch 39/39
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2814 - accuracy: 0.8822
# Epoch 40/40
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2815 - accuracy: 0.8827
# Epoch 41/41
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2796 - accuracy: 0.8840
# Epoch 42/42
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2806 - accuracy: 0.8840
# Epoch 43/43
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2754 - accuracy: 0.8847
# Epoch 44/44
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2769 - accuracy: 0.8871
# Epoch 45/45
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2758 - accuracy: 0.8873
# Epoch 46/46
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2747 - accuracy: 0.8856
# Epoch 47/47
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.8865
# Epoch 48/48
# 204/204 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.8874
# Epoch 49/49
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2736 - accuracy: 0.8845
# Epoch 50/50
# 204/204 [==============================] - 1s 2ms/step - loss: 0.2740 - accuracy: 0.8842
# updating: content/js_export/ (stored 0%)
# updating: content/js_export/vocab.txt (deflated 60%)
# updating: content/js_export/labels.txt (stored 0%)
# updating: content/js_export/tfjs/ (stored 0%)
# updating: content/js_export/tfjs/model.json (deflated 72%)
# updating: content/js_export/tfjs/group1-shard1of1.bin (deflated 7%)
